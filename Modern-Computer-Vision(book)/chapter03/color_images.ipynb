# %%
# !wget https://www.cartacapital.com.br/wp-content/uploads/2021/01/Bolsonaro-Impeachment-1.jpg
# Out:
# --2021-02-06 19:49:24--  https://www.cartacapital.com.br/wp-content/uploads/2021/01/Bolsonaro-Impeachment-1.jpg
# Resolving www.cartacapital.com.br (www.cartacapital.com.br)... 2606:4700:20::ac43:48df, 2606:4700:20::681a:9b7, 2606:4700:20::681a:8b7, ...
# Connecting to www.cartacapital.com.br (www.cartacapital.com.br)|2606:4700:20::ac43:48df|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: 'Bolsonaro-Impeachment-1.jpg'
#
# Bolsonaro-Impeachme     [  <=>               ] 126.25K   434KB/s    in 0.3s
#
# 2021-02-06 19:49:25 (434 KB/s) - 'Bolsonaro-Impeachment-1.jpg' saved [129285]

# %%
import cv2, matplotlib.pyplot as plt
# %matplotlib inline
img = cv2.imread('Bolsonaro-Impeachment-1.jpg')

# %%
img = img[50:380,500:850,:]
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
print(img.shape)
# Out:
# (330, 350, 3)

# %%
crop = img[-3:,-3:]

# %%
print(crop)
plt.imshow(crop)
# Out:
# [[[25 29 40]
#   [25 29 38]
#   [29 33 42]]
#
#  [[21 25 36]
#   [24 28 37]
#   [29 33 42]]
#
#  [[19 23 34]
#   [20 24 33]
#   [24 28 37]]]
